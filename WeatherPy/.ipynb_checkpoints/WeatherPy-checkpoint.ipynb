# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
# Had to pip install citipy into my anaconda python 3.7 environment
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# This is ugly, but I'm slicing my city list down into batches
# I'm sure that there is a more efficient way to do this
# I assume that the batch size of 50 is to preven api key from being blocked?

city_slice1 = cities[0:50]
city_slice2 = cities[50:100]
city_slice3 = cities[100:150]
city_slice4 = cities[150:200]
city_slice5 = cities[200:250]
city_slice6 = cities[250:300]
city_slice7 = cities[300:350]
city_slice8 = cities[350:400]
city_slice9 = cities[400:450]
city_slice10 = cities[450:500]
city_slice11 = cities[500:550]
city_slice12 = cities[550:600]
city_slice13 = cities[600:]

city_slices = [city_slice1,
              city_slice1,
              city_slice2,
              city_slice3,
              city_slice4,
              city_slice5,
              city_slice6,
              city_slice7,
              city_slice8,
              city_slice9,
              city_slice10,
              city_slice11,
              city_slice12,
              city_slice13]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

city_list = []
cloud_list = []
country_list = []
date_list = []
humid_list = []
lat_list = []
long_list = []
temp_max_list = []
wind_list = []

record_num = 1
set_num = 1


# Loop to iterate through cities
# build query url with current city
# get response and append data to lists

print("Beginning Data Retrieval")
print ("-----------------------------")


for slice in city_slices:
    for c in slice:
        try:
            query_url = url + "appid=" + api_key + "&q=" + c + "&units=imperial"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            print(f"Processing Record {record_num} of set {set_num} | {weather_json['name']}" )
            city_list.append(weather_json['name'])
            cloud_list.append(weather_json['clouds']['all'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])
            humid_list.append(weather_json['main']['humidity'])
            lat_list.append(weather_json['coord']['lat'])
            long_list.append(weather_json['coord']['lon'])
            temp_max_list.append(weather_json['main']['temp_max'])
            wind_list.append(weather_json['wind']['speed'])
        except KeyError:
            print(f"Whoops,  City {c} does not exist, skipping")
        record_num +=1
    set_num +=1
    record_num =1              

print ("-----------------------------")
print("Data Retrieval Complete")
print ("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Whoops,  City sentyabrskiy does not exist, skipping
# Processing Record 2 of set 1 | Kavieng
# Processing Record 3 of set 1 | Faanui
# Processing Record 4 of set 1 | Arraial do Cabo
# Processing Record 5 of set 1 | Vaini
# Processing Record 6 of set 1 | Hailey
# Processing Record 7 of set 1 | Gushikawa
# Processing Record 8 of set 1 | Albany
# Processing Record 9 of set 1 | Cape Town
# Processing Record 10 of set 1 | Luanda
# Processing Record 11 of set 1 | Port Alfred
# Processing Record 12 of set 1 | Ushuaia
# Processing Record 13 of set 1 | Rikitea
# Processing Record 14 of set 1 | Timmins
# Processing Record 15 of set 1 | Hermanus
# Whoops,  City taolanaro does not exist, skipping
# Whoops,  City belushya guba does not exist, skipping
# Processing Record 18 of set 1 | Port Elizabeth
# Processing Record 19 of set 1 | Lompoc
# Processing Record 20 of set 1 | Punta Arenas
# Processing Record 21 of set 1 | Clyde River
# Processing Record 22 of set 1 | New Norfolk
# Processing Record 23 of set 1 | Santa Fe
# Processing Record 24 of set 1 | Nanortalik
# Processing Record 25 of set 1 | Lorengau
# Processing Record 26 of set 1 | Hobart
# Processing Record 27 of set 1 | Yar-Sale
# Processing Record 28 of set 1 | Kaeo
# Processing Record 29 of set 1 | Sitka
# Processing Record 30 of set 1 | Pangnirtung
# Processing Record 31 of set 1 | Cherskiy
# Processing Record 32 of set 1 | Saldanha
# Processing Record 33 of set 1 | Upernavik
# Processing Record 34 of set 1 | Tasiilaq
# Processing Record 35 of set 1 | Atuona
# Processing Record 36 of set 1 | Iqaluit
# Processing Record 37 of set 1 | Mount Gambier
# Processing Record 38 of set 1 | Whitehaven
# Processing Record 39 of set 1 | Yellowknife
# Processing Record 40 of set 1 | Roald
# Processing Record 41 of set 1 | Jamestown
# Processing Record 42 of set 1 | Longyearbyen
# Processing Record 43 of set 1 | Bogalusa
# Processing Record 44 of set 1 | Agirish
# Processing Record 45 of set 1 | Mataura
# Whoops,  City labrea does not exist, skipping
# Processing Record 47 of set 1 | Busselton
# Whoops,  City grand river south east does not exist, skipping
# Processing Record 49 of set 1 | Qaanaaq
# Processing Record 50 of set 1 | Saint-Georges
# Whoops,  City sentyabrskiy does not exist, skipping
# Processing Record 2 of set 2 | Kavieng
# Processing Record 3 of set 2 | Faanui
# Processing Record 4 of set 2 | Arraial do Cabo
# Processing Record 5 of set 2 | Vaini
# Processing Record 6 of set 2 | Hailey
# Processing Record 7 of set 2 | Gushikawa
# Processing Record 8 of set 2 | Albany
# Processing Record 9 of set 2 | Cape Town
# Processing Record 10 of set 2 | Luanda
# Processing Record 11 of set 2 | Port Alfred
# Processing Record 12 of set 2 | Ushuaia
# Processing Record 13 of set 2 | Rikitea
# Processing Record 14 of set 2 | Timmins
# Processing Record 15 of set 2 | Hermanus
# Whoops,  City taolanaro does not exist, skipping
# Whoops,  City belushya guba does not exist, skipping
# Processing Record 18 of set 2 | Port Elizabeth
# Processing Record 19 of set 2 | Lompoc
# Processing Record 20 of set 2 | Punta Arenas
# Processing Record 21 of set 2 | Clyde River
# Processing Record 22 of set 2 | New Norfolk
# Processing Record 23 of set 2 | Santa Fe
# Processing Record 24 of set 2 | Nanortalik
# Processing Record 25 of set 2 | Lorengau
# Processing Record 26 of set 2 | Hobart
# Processing Record 27 of set 2 | Yar-Sale
# Processing Record 28 of set 2 | Kaeo
# Processing Record 29 of set 2 | Sitka
# Processing Record 30 of set 2 | Pangnirtung
# Processing Record 31 of set 2 | Cherskiy
# Processing Record 32 of set 2 | Saldanha
# Processing Record 33 of set 2 | Upernavik
# Processing Record 34 of set 2 | Tasiilaq
# Processing Record 35 of set 2 | Atuona
# Processing Record 36 of set 2 | Iqaluit
# Processing Record 37 of set 2 | Mount Gambier
# Processing Record 38 of set 2 | Whitehaven
# Processing Record 39 of set 2 | Yellowknife
# Processing Record 40 of set 2 | Roald
# Processing Record 41 of set 2 | Jamestown
# Processing Record 42 of set 2 | Longyearbyen
# Processing Record 43 of set 2 | Bogalusa
# Processing Record 44 of set 2 | Agirish
# Processing Record 45 of set 2 | Mataura
# Whoops,  City labrea does not exist, skipping
# Processing Record 47 of set 2 | Busselton
# Whoops,  City grand river south east does not exist, skipping
# Processing Record 49 of set 2 | Qaanaaq
# Processing Record 50 of set 2 | Saint-Georges
# Processing Record 1 of set 3 | Bambous Virieux
# Processing Record 2 of set 3 | Sao Raimundo das Mangabeiras
# Processing Record 3 of set 3 | Vostok
# Processing Record 4 of set 3 | Bredasdorp
# Processing Record 5 of set 3 | Hervey Bay
# Processing Record 6 of set 3 | Laguna
# Processing Record 7 of set 3 | Mecca
# Processing Record 8 of set 3 | Sepuka
# Processing Record 9 of set 3 | Kahului
# Processing Record 10 of set 3 | Tulcea
# Processing Record 11 of set 3 | Ponta do Sol
# Processing Record 12 of set 3 | Khatanga
# Processing Record 13 of set 3 | Hithadhoo
# Processing Record 14 of set 3 | Gat
# Processing Record 15 of set 3 | Mar del Plata
# Processing Record 16 of set 3 | Barrow
# Processing Record 17 of set 3 | Bluff
# Whoops,  City longlac does not exist, skipping
# Processing Record 19 of set 3 | Uruzgan
# Processing Record 20 of set 3 | Saint George
# Processing Record 21 of set 3 | Nome
# Processing Record 22 of set 3 | Portland
# Processing Record 23 of set 3 | La Libertad
# Processing Record 24 of set 3 | Magadan
# Processing Record 25 of set 3 | Bathsheba
# Processing Record 26 of set 3 | Ancud
# Whoops,  City tabiauea does not exist, skipping
# Processing Record 28 of set 3 | Warrington
# Processing Record 29 of set 3 | Luderitz
# Processing Record 30 of set 3 | Henties Bay
# Processing Record 31 of set 3 | Rosarito
# Processing Record 32 of set 3 | Hilo
# Processing Record 33 of set 3 | Saint-Philippe
# Processing Record 34 of set 3 | Nisia Floresta
# Processing Record 35 of set 3 | San Cristobal
# Processing Record 36 of set 3 | Basco
# Processing Record 37 of set 3 | Severo-Kurilsk
# Processing Record 38 of set 3 | Kloulklubed
# Processing Record 39 of set 3 | Hasaki
# Processing Record 40 of set 3 | Provideniya
# Processing Record 41 of set 3 | Morant Bay
# Processing Record 42 of set 3 | Sao Filipe
# Whoops,  City beruni does not exist, skipping
# Whoops,  City warqla does not exist, skipping
# Processing Record 45 of set 3 | Port Hardy
# Processing Record 46 of set 3 | Cidreira
# Processing Record 47 of set 3 | Winton
# Processing Record 48 of set 3 | Mahebourg
# Processing Record 49 of set 3 | Saskylakh
# Processing Record 50 of set 3 | Union City
# Processing Record 1 of set 4 | General Roca
# Processing Record 2 of set 4 | Victoria
# Processing Record 3 of set 4 | Thompson
# Processing Record 4 of set 4 | Zhuhai
# Whoops,  City illoqqortoormiut does not exist, skipping
# Processing Record 6 of set 4 | Dhidhdhoo
# Processing Record 7 of set 4 | High Level
# Processing Record 8 of set 4 | Navalmoral de la Mata
# Processing Record 9 of set 4 | Husavik
# Processing Record 10 of set 4 | Lamar
# Whoops,  City mys shmidta does not exist, skipping
# Processing Record 12 of set 4 | Bambanglipuro
# Processing Record 13 of set 4 | Ilulissat
# Processing Record 14 of set 4 | Puerto Ayora
# Processing Record 15 of set 4 | Salalah
# Processing Record 16 of set 4 | Esperance
# Processing Record 17 of set 4 | Yining
# Processing Record 18 of set 4 | Avarua
# Processing Record 19 of set 4 | Turayf
# Whoops,  City maykain does not exist, skipping
# Whoops,  City cumaribo does not exist, skipping
# Whoops,  City aflu does not exist, skipping
# Processing Record 23 of set 4 | Norman Wells
# Whoops,  City lolua does not exist, skipping
# Processing Record 25 of set 4 | Bosaso
# Processing Record 26 of set 4 | Lethem
# Processing Record 27 of set 4 | Puerto del Rosario
# Processing Record 28 of set 4 | Mayor Pablo Lagerenza
# Processing Record 29 of set 4 | Lichtenburg
# Processing Record 30 of set 4 | Faya
# Processing Record 31 of set 4 | Leningradskiy
# Processing Record 32 of set 4 | Corralillo
# Processing Record 33 of set 4 | Wewak
# Processing Record 34 of set 4 | Puyang
# Processing Record 35 of set 4 | Bull Savanna
# Processing Record 36 of set 4 | Tilichiki
# Processing Record 37 of set 4 | Ribeira Grande
# Processing Record 38 of set 4 | Kaitangata
# Processing Record 39 of set 4 | Nikolskoye
# Processing Record 40 of set 4 | Khislavichi
# Processing Record 41 of set 4 | Port Lincoln
# Processing Record 42 of set 4 | Geraldton
# Processing Record 43 of set 4 | Peniche
# Processing Record 44 of set 4 | Soyo
# Processing Record 45 of set 4 | Cradock
# Whoops,  City cagayan de tawi-tawi does not exist, skipping
# Processing Record 47 of set 4 | Beringovskiy
# Processing Record 48 of set 4 | Castro
# Processing Record 49 of set 4 | Ternate
# Processing Record 50 of set 4 | Lata
# Whoops,  City bolshoye pikino does not exist, skipping
# Processing Record 2 of set 5 | Slavyanka
# Processing Record 3 of set 5 | Turbat
# Processing Record 4 of set 5 | Namie
# Processing Record 5 of set 5 | Adrar
# Processing Record 6 of set 5 | Ponta Delgada
# Processing Record 7 of set 5 | Caicedo
# Whoops,  City tsihombe does not exist, skipping
# Processing Record 9 of set 5 | Russell
# Processing Record 10 of set 5 | Cap Malheureux
# Processing Record 11 of set 5 | Dekar
# Processing Record 12 of set 5 | Beruwala
# Processing Record 13 of set 5 | Broome
# Processing Record 14 of set 5 | Fort Portal
# Processing Record 15 of set 5 | Tautira
# Processing Record 16 of set 5 | Klaksvik
# Processing Record 17 of set 5 | Aklavik
# Whoops,  City asau does not exist, skipping
# Whoops,  City marcona does not exist, skipping
# Processing Record 20 of set 5 | Zhigalovo
# Processing Record 21 of set 5 | Rincon
# Processing Record 22 of set 5 | Fortuna
# Processing Record 23 of set 5 | Lebu
# Processing Record 24 of set 5 | Ahuimanu
# Processing Record 25 of set 5 | Kodiak
# Processing Record 26 of set 5 | Kijang
# Processing Record 27 of set 5 | Riyadh
# Processing Record 28 of set 5 | Vitry-le-Francois
# Processing Record 29 of set 5 | Lewiston
# Processing Record 30 of set 5 | Lavrentiya
# Processing Record 31 of set 5 | Torzhok
# Processing Record 32 of set 5 | Bethel
# Processing Record 33 of set 5 | Georgetown
# Processing Record 34 of set 5 | Padang
# Processing Record 35 of set 5 | Namatanai
# Processing Record 36 of set 5 | Khasan
# Processing Record 37 of set 5 | Maksatikha
# Processing Record 38 of set 5 | Hamilton
# Whoops,  City amderma does not exist, skipping
# Processing Record 40 of set 5 | Cayenne
# Whoops,  City turtkul does not exist, skipping
# Processing Record 42 of set 5 | Dingle
# Processing Record 43 of set 5 | Kotka
# Processing Record 44 of set 5 | Guerrero Negro
# Whoops,  City rawannawi does not exist, skipping
# Processing Record 46 of set 5 | Bilibino
# Whoops,  City sakakah does not exist, skipping
# Processing Record 48 of set 5 | Mount Isa
# Processing Record 49 of set 5 | Tuktoyaktuk
# Processing Record 50 of set 5 | Yaan
# Processing Record 1 of set 6 | Auxerre
# Processing Record 2 of set 6 | Ahipara
# Processing Record 3 of set 6 | Butaritari
# Processing Record 4 of set 6 | Carnarvon
# Processing Record 5 of set 6 | Vung Tau
# Processing Record 6 of set 6 | Boffa
# Processing Record 7 of set 6 | Kemise
# Processing Record 8 of set 6 | Manzhouli
# Processing Record 9 of set 6 | Kapaa
# Processing Record 10 of set 6 | Endicott
# Whoops,  City tidore does not exist, skipping
# Processing Record 12 of set 6 | Nicoya
# Whoops,  City saleaula does not exist, skipping
# Processing Record 14 of set 6 | East London
# Processing Record 15 of set 6 | Constitucion
# Processing Record 16 of set 6 | Onega
# Processing Record 17 of set 6 | Atasu
# Processing Record 18 of set 6 | Tessalit
# Processing Record 19 of set 6 | Henderson
# Processing Record 20 of set 6 | Boulsa
# Processing Record 21 of set 6 | Isangel
# Processing Record 22 of set 6 | Flinders
# Processing Record 23 of set 6 | Kalianget
# Processing Record 24 of set 6 | Bowmore
# Processing Record 25 of set 6 | Sisimiut
# Processing Record 26 of set 6 | Haines Junction
# Processing Record 27 of set 6 | Jacareacanga
# Whoops,  City attawapiskat does not exist, skipping
# Processing Record 29 of set 6 | Sorland
# Processing Record 30 of set 6 | Airai
# Processing Record 31 of set 6 | Comodoro Rivadavia
# Processing Record 32 of set 6 | Broken Hill
# Processing Record 33 of set 6 | Ajaccio
# Processing Record 34 of set 6 | Dinard
# Processing Record 35 of set 6 | Kruisfontein
# Processing Record 36 of set 6 | Abu Zabad
# Processing Record 37 of set 6 | Vestmanna
# Processing Record 38 of set 6 | Manali
# Processing Record 39 of set 6 | Lagoa
# Processing Record 40 of set 6 | Almaznyy
# Processing Record 41 of set 6 | Souillac
# Processing Record 42 of set 6 | Abonnema
# Processing Record 43 of set 6 | Alamogordo
# Processing Record 44 of set 6 | Mokobeng
# Processing Record 45 of set 6 | Deputatskiy
# Processing Record 46 of set 6 | Marquette
# Whoops,  City manzil tamim does not exist, skipping
# Processing Record 48 of set 6 | Mednogorsk
# Processing Record 49 of set 6 | Murdochville
# Whoops,  City tahta does not exist, skipping
# Processing Record 1 of set 7 | Vanimo
# Processing Record 2 of set 7 | Grindavik
# Processing Record 3 of set 7 | Siverek
# Processing Record 4 of set 7 | Guano
# Processing Record 5 of set 7 | Lao Cai
# Processing Record 6 of set 7 | Naze
# Whoops,  City toliary does not exist, skipping
# Processing Record 8 of set 7 | Chuy
# Processing Record 9 of set 7 | Kampene
# Processing Record 10 of set 7 | Chapais
# Processing Record 11 of set 7 | Huarmey
# Processing Record 12 of set 7 | Ocamonte
# Processing Record 13 of set 7 | College Place
# Processing Record 14 of set 7 | Contai
# Processing Record 15 of set 7 | Sao Felix do Xingu
# Processing Record 16 of set 7 | Miyang
# Processing Record 17 of set 7 | Maxixe
# Processing Record 18 of set 7 | Tifton
# Processing Record 19 of set 7 | Brae
# Processing Record 20 of set 7 | La Tuque
# Processing Record 21 of set 7 | Katherine
# Processing Record 22 of set 7 | Sicuani
# Processing Record 23 of set 7 | Ghatampur
# Whoops,  City barentsburg does not exist, skipping
# Processing Record 25 of set 7 | Okhotsk
# Processing Record 26 of set 7 | Raseiniai
# Processing Record 27 of set 7 | Hami
# Whoops,  City ruatoria does not exist, skipping
# Processing Record 29 of set 7 | Ambilobe
# Processing Record 30 of set 7 | Ola
# Processing Record 31 of set 7 | Benguela
# Processing Record 32 of set 7 | Latung
# Whoops,  City we does not exist, skipping
# Processing Record 34 of set 7 | Nouadhibou
# Processing Record 35 of set 7 | Centralia
# Whoops,  City halalo does not exist, skipping
# Processing Record 37 of set 7 | Atbasar
# Processing Record 38 of set 7 | Coroata
# Processing Record 39 of set 7 | Komsomolskiy
# Processing Record 40 of set 7 | Vaitape
# Processing Record 41 of set 7 | Tiksi
# Processing Record 42 of set 7 | Los Llanos de Aridane
# Processing Record 43 of set 7 | Mitha Tiwana
# Processing Record 44 of set 7 | Rio Cuarto
# Whoops,  City nizhneyansk does not exist, skipping
# Whoops,  City mahadday weyne does not exist, skipping
# Processing Record 47 of set 7 | Talcahuano
# Processing Record 48 of set 7 | Tela
# Processing Record 49 of set 7 | Eyl
# Processing Record 50 of set 7 | Altamira
# Processing Record 1 of set 8 | Asyut
# Processing Record 2 of set 8 | Kalmunai
# Processing Record 3 of set 8 | Ust-Omchug
# Processing Record 4 of set 8 | Aboyne
# Processing Record 5 of set 8 | Tuy Hoa
# Processing Record 6 of set 8 | Vila Velha
# Processing Record 7 of set 8 | Paamiut
# Processing Record 8 of set 8 | Shizuishan
# Processing Record 9 of set 8 | Uthal
# Processing Record 10 of set 8 | Katsuura
# Processing Record 11 of set 8 | Berga
# Processing Record 12 of set 8 | Muros
# Processing Record 13 of set 8 | Pozhva
# Processing Record 14 of set 8 | Tazovskiy
# Processing Record 15 of set 8 | Ossora
# Processing Record 16 of set 8 | Balkhash
# Whoops,  City samusu does not exist, skipping
# Processing Record 18 of set 8 | Wonogiri
# Whoops,  City lar gerd does not exist, skipping
# Processing Record 20 of set 8 | Chokurdakh
# Processing Record 21 of set 8 | Taiyuan
# Processing Record 22 of set 8 | Alofi
# Processing Record 23 of set 8 | Witbank
# Processing Record 24 of set 8 | Abu Samrah
# Whoops,  City bargal does not exist, skipping
# Processing Record 26 of set 8 | Dikson
# Processing Record 27 of set 8 | Kiunga
# Processing Record 28 of set 8 | Zavitinsk
# Processing Record 29 of set 8 | Lazaro Cardenas
# Processing Record 30 of set 8 | Coihaique
# Processing Record 31 of set 8 | Caravelas
# Processing Record 32 of set 8 | Altay
# Processing Record 33 of set 8 | Srandakan
# Processing Record 34 of set 8 | Rio Grande
# Whoops,  City bengkulu does not exist, skipping
# Processing Record 36 of set 8 | Biryusinsk
# Processing Record 37 of set 8 | Mitsamiouli
# Processing Record 38 of set 8 | Lososina
# Processing Record 39 of set 8 | Port-Gentil
# Processing Record 40 of set 8 | Teacapan
# Processing Record 41 of set 8 | Vanavara
# Processing Record 42 of set 8 | Miri
# Processing Record 43 of set 8 | Poum
# Processing Record 44 of set 8 | Mollendo
# Processing Record 45 of set 8 | Sura
# Processing Record 46 of set 8 | Saint Anthony
# Processing Record 47 of set 8 | Goderich
# Processing Record 48 of set 8 | Artsvaberd
# Processing Record 49 of set 8 | Presidente Olegario
# Whoops,  City ust-kamchatsk does not exist, skipping
# Whoops,  City utiroa does not exist, skipping
# Processing Record 2 of set 9 | Kenitra
# Processing Record 3 of set 9 | Jalu
# Whoops,  City alotau does not exist, skipping
# Processing Record 5 of set 9 | Brewster
# Processing Record 6 of set 9 | Ostrovnoy
# Processing Record 7 of set 9 | Ahar
# Processing Record 8 of set 9 | Buin
# Processing Record 9 of set 9 | Srednekolymsk
# Processing Record 10 of set 9 | Brigantine
# Processing Record 11 of set 9 | Barinitas
# Processing Record 12 of set 9 | Zeerust
# Processing Record 13 of set 9 | Sandakan
# Processing Record 14 of set 9 | Weyburn
# Processing Record 15 of set 9 | Sur
# Processing Record 16 of set 9 | Waddan
# Processing Record 17 of set 9 | Namibe
# Processing Record 18 of set 9 | Moose Factory
# Processing Record 19 of set 9 | Kouango
# Processing Record 20 of set 9 | Nioro
# Processing Record 21 of set 9 | Hokitika
# Processing Record 22 of set 9 | Ulaanbaatar
# Processing Record 23 of set 9 | Chukhloma
# Processing Record 24 of set 9 | Sao Gabriel da Cachoeira
# Whoops,  City leer does not exist, skipping
# Whoops,  City safwah does not exist, skipping
# Processing Record 27 of set 9 | Hambantota
# Processing Record 28 of set 9 | Fort Nelson
# Processing Record 29 of set 9 | Bandarbeyla
# Processing Record 30 of set 9 | Axim
# Processing Record 31 of set 9 | Horki
# Processing Record 32 of set 9 | Pedana
# Processing Record 33 of set 9 | Neiafu
# Processing Record 34 of set 9 | Manokwari
# Processing Record 35 of set 9 | Shenjiamen
# Processing Record 36 of set 9 | Zacatecas
# Processing Record 37 of set 9 | Itarema
# Processing Record 38 of set 9 | Bani Walid
# Whoops,  City tumannyy does not exist, skipping
# Processing Record 40 of set 9 | Santa Vitoria do Palmar
# Processing Record 41 of set 9 | Berlevag
# Processing Record 42 of set 9 | Sunrise Manor
# Processing Record 43 of set 9 | Dakar
# Whoops,  City khonuu does not exist, skipping
# Processing Record 45 of set 9 | Ostersund
# Processing Record 46 of set 9 | Gulistan
# Processing Record 47 of set 9 | Payson
# Processing Record 48 of set 9 | Innisfail
# Processing Record 49 of set 9 | Gbarnga
# Whoops,  City krasnoselkup does not exist, skipping
# Processing Record 1 of set 10 | Pisco
# Processing Record 2 of set 10 | Chenghai
# Processing Record 3 of set 10 | Praia da Vitoria
# Processing Record 4 of set 10 | Pecos
# Processing Record 5 of set 10 | Tuatapere
# Processing Record 6 of set 10 | Hargeysa
# Processing Record 7 of set 10 | Hualmay
# Processing Record 8 of set 10 | Tulare
# Processing Record 9 of set 10 | Big Rapids
# Processing Record 10 of set 10 | Elk City
# Processing Record 11 of set 10 | Dunedin
# Processing Record 12 of set 10 | Siva
# Processing Record 13 of set 10 | Tugulym
# Processing Record 14 of set 10 | Coahuayana
# Whoops,  City khania does not exist, skipping
# Processing Record 16 of set 10 | Vila Franca do Campo
# Processing Record 17 of set 10 | Launceston
# Whoops,  City bur gabo does not exist, skipping
# Whoops,  City vaovai does not exist, skipping
# Processing Record 20 of set 10 | Porto Novo
# Whoops,  City tawkar does not exist, skipping
# Whoops,  City jaipur hat does not exist, skipping
# Processing Record 23 of set 10 | College
# Processing Record 24 of set 10 | Dennery
# Processing Record 25 of set 10 | Saint-Augustin
# Processing Record 26 of set 10 | Arys
# Whoops,  City makung does not exist, skipping
# Processing Record 28 of set 10 | Quibdo
# Processing Record 29 of set 10 | Port Hedland
# Whoops,  City kuche does not exist, skipping
# Processing Record 31 of set 10 | Torbay
# Whoops,  City maghama does not exist, skipping
# Processing Record 33 of set 10 | Kawalu
# Processing Record 34 of set 10 | Kovernino
# Processing Record 35 of set 10 | Vuktyl
# Processing Record 36 of set 10 | Erenhot
# Whoops,  City rungata does not exist, skipping
# Processing Record 38 of set 10 | Cabo San Lucas
# Processing Record 39 of set 10 | Preobrazheniye
# Processing Record 40 of set 10 | Voh
# Processing Record 41 of set 10 | Foki
# Processing Record 42 of set 10 | Beira
# Processing Record 43 of set 10 | San Carlos de Bariloche
# Whoops,  City iringa does not exist, skipping
# Whoops,  City pemangkat does not exist, skipping
# Processing Record 46 of set 10 | Anloga
# Processing Record 47 of set 10 | Saint-Pierre
# Processing Record 48 of set 10 | Balakhninskiy
# Processing Record 49 of set 10 | Sergach
# Processing Record 50 of set 10 | Muzhi
# Processing Record 1 of set 11 | Mandiana
# Processing Record 2 of set 11 | Palmer
# Processing Record 3 of set 11 | Khorixas
# Whoops,  City maridi does not exist, skipping
# Processing Record 5 of set 11 | Coquimbo
# Processing Record 6 of set 11 | Canete
# Processing Record 7 of set 11 | Vardo
# Processing Record 8 of set 11 | Smolyaninovo
# Processing Record 9 of set 11 | Ciudad Bolivar
# Processing Record 10 of set 11 | Along
# Processing Record 11 of set 11 | Anadyr
# Processing Record 12 of set 11 | Sao Joao da Barra
# Processing Record 13 of set 11 | Mutsu
# Whoops,  City yirol does not exist, skipping
# Processing Record 15 of set 11 | Contamana
# Processing Record 16 of set 11 | Praia
# Processing Record 17 of set 11 | Miragoane
# Processing Record 18 of set 11 | Petropavlovsk-Kamchatskiy
# Processing Record 19 of set 11 | Cairns
# Processing Record 20 of set 11 | Lakselv
# Processing Record 21 of set 11 | Nakhon Thai
# Processing Record 22 of set 11 | Springbok
# Processing Record 23 of set 11 | Altar
# Processing Record 24 of set 11 | Yakeshi
# Processing Record 25 of set 11 | Hofn
# Processing Record 26 of set 11 | Awjilah
# Processing Record 27 of set 11 | Codrington
# Processing Record 28 of set 11 | Billings
# Processing Record 29 of set 11 | Sangar
# Processing Record 30 of set 11 | Atocha
# Processing Record 31 of set 11 | Fairbanks
# Processing Record 32 of set 11 | Lanigan
# Processing Record 33 of set 11 | Puerto Lempira
# Processing Record 34 of set 11 | Pahrump
# Processing Record 35 of set 11 | Santiago
# Processing Record 36 of set 11 | Cuenca
# Processing Record 37 of set 11 | Beyneu
# Processing Record 38 of set 11 | Barguzin
# Processing Record 39 of set 11 | Rawson
# Processing Record 40 of set 11 | Hit
# Processing Record 41 of set 11 | Yulara
# Whoops,  City kamenskoye does not exist, skipping
# Processing Record 43 of set 11 | Saint-Francois
# Whoops,  City berbera does not exist, skipping
# Processing Record 45 of set 11 | Boca do Acre
# Processing Record 46 of set 11 | Paita
# Whoops,  City sumbawa does not exist, skipping
# Processing Record 48 of set 11 | Quang Ngai
# Processing Record 49 of set 11 | Bucerias
# Processing Record 50 of set 11 | Perth
# Processing Record 1 of set 12 | Mwinilunga
# Processing Record 2 of set 12 | Sausar
# Processing Record 3 of set 12 | Egvekinot
# Processing Record 4 of set 12 | Harper
# Whoops,  City olafsvik does not exist, skipping
# Processing Record 6 of set 12 | Rosoman
# Processing Record 7 of set 12 | Hearst
# Processing Record 8 of set 12 | Albury
# Processing Record 9 of set 12 | Bourges
# Processing Record 10 of set 12 | Terney
# Processing Record 11 of set 12 | Xuddur
# Processing Record 12 of set 12 | Gamba
# Processing Record 13 of set 12 | Malatya
# Processing Record 14 of set 12 | Dolores
# Whoops,  City itapua poty does not exist, skipping
# Processing Record 16 of set 12 | Svetlogorsk
# Processing Record 17 of set 12 | Kanlagay
# Processing Record 18 of set 12 | Avera
# Processing Record 19 of set 12 | Miroslav
# Processing Record 20 of set 12 | Cambridge
# Processing Record 21 of set 12 | Mitu
# Processing Record 22 of set 12 | Ambo
# Processing Record 23 of set 12 | North Branch
# Processing Record 24 of set 12 | Birjand
# Processing Record 25 of set 12 | Kadaya
# Processing Record 26 of set 12 | Harindanga
# Processing Record 27 of set 12 | Dukat
# Processing Record 28 of set 12 | Taoudenni
# Processing Record 29 of set 12 | Marseille
# Processing Record 30 of set 12 | Mayumba
# Processing Record 31 of set 12 | Talnakh
# Processing Record 32 of set 12 | Qaqortoq
# Processing Record 33 of set 12 | Shelburne
# Processing Record 34 of set 12 | Andijan
# Processing Record 35 of set 12 | Kandrian
# Processing Record 36 of set 12 | Key West
# Processing Record 37 of set 12 | Andros Town
# Processing Record 38 of set 12 | Den Helder
# Processing Record 39 of set 12 | Touros
# Whoops,  City mahaicony does not exist, skipping
# Processing Record 41 of set 12 | Conde
# Processing Record 42 of set 12 | Iranshahr
# Processing Record 43 of set 12 | Mbekenyera
# Processing Record 44 of set 12 | Novobiryusinskiy
# Processing Record 45 of set 12 | Oulu
# Processing Record 46 of set 12 | Kuusamo
# Processing Record 47 of set 12 | Touba
# Whoops,  City vaitupu does not exist, skipping
# Processing Record 49 of set 12 | Milkovo
# Processing Record 50 of set 12 | Bukama
# Processing Record 1 of set 13 | Vila
# Processing Record 2 of set 13 | Ugoofaaru
# Processing Record 3 of set 13 | Salinopolis
# Processing Record 4 of set 13 | Turukhansk
# Processing Record 5 of set 13 | Iquique
# Processing Record 6 of set 13 | Havre-Saint-Pierre
# Whoops,  City palabuhanratu does not exist, skipping
# Processing Record 8 of set 13 | Sao Paulo de Olivenca
# Processing Record 9 of set 13 | Santa Maria
# Processing Record 10 of set 13 | Itapicuru
# Processing Record 11 of set 13 | Meulaboh
# Processing Record 12 of set 13 | North Platte
# Processing Record 13 of set 13 | Gorontalo
# Processing Record 14 of set 13 | Fuxin
# Processing Record 15 of set 13 | Tyukhtet
# Processing Record 16 of set 13 | Angers
# Processing Record 17 of set 13 | Chumikan
# Processing Record 18 of set 13 | Nerchinskiy Zavod
# Processing Record 19 of set 13 | West Wendover
# Processing Record 20 of set 13 | Santa Rosa
# Processing Record 21 of set 13 | Alice Springs
# Whoops,  City louisbourg does not exist, skipping
# Processing Record 23 of set 13 | Cabedelo
# Processing Record 24 of set 13 | Makat
# Processing Record 25 of set 13 | Mamakan
# Processing Record 26 of set 13 | Loandjili
# Whoops,  City zhanatas does not exist, skipping
# Processing Record 28 of set 13 | Kalemie
# Processing Record 29 of set 13 | Muroto
# Processing Record 30 of set 13 | Bani
# Processing Record 31 of set 13 | Oussouye
# Processing Record 32 of set 13 | Tacna
# Processing Record 33 of set 13 | Linfen
# Whoops,  City skalistyy does not exist, skipping
# Processing Record 35 of set 13 | Jizan
# Processing Record 36 of set 13 | Vallenar
# Processing Record 37 of set 13 | Ambon
# Processing Record 38 of set 13 | Kulhudhuffushi
# Whoops,  City bac lieu does not exist, skipping
# Processing Record 40 of set 13 | Mackay
# Processing Record 41 of set 13 | Bonthe
# Whoops,  City taburi does not exist, skipping
# Processing Record 43 of set 13 | Meadow Lake
# Processing Record 44 of set 13 | Prince Rupert
# Whoops,  City karamea does not exist, skipping
# Processing Record 46 of set 13 | Pacific Grove
# Processing Record 47 of set 13 | Two Rivers
# Processing Record 48 of set 13 | Yerbogachen
# Whoops,  City grand centre does not exist, skipping
# Processing Record 50 of set 13 | Marrakesh
# Processing Record 1 of set 14 | Krapkowice
# Processing Record 2 of set 14 | San Andres
# Processing Record 3 of set 14 | Springfield
# Processing Record 4 of set 14 | Rio Bueno
# Processing Record 5 of set 14 | Stony Plain
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloud_list,
    "Country": country_list,
    "Date": date_list,
    "Humidity": humid_list,
    "Lat": lat_list,
    "Lng": long_list,
    "Max Temp": temp_max_list,
    "Wind Speed": wind_list
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
weather_data.to_csv('output/weather_data.csv', encoding='utf-8')

# %%
weather_data.head(5)
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Kavieng          86      PG  1576088385        72  -2.57  150.80
# 1           Faanui          96      PF  1576088385        76 -16.48 -151.75
# 2  Arraial do Cabo          75      BR  1576088385        83 -22.97  -42.02
# 3            Vaini          40      IN  1576088385        76  15.34   74.49
# 4           Hailey          90      US  1576088386        79  43.52 -114.32
#
#    Max Temp  Wind Speed
# 0     84.31        8.55
# 1     80.17       11.88
# 2     78.80        9.17
# 3     65.88        2.59
# 4     28.40        6.93

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Max Temperature ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("images/city_lat_vs_max_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Humidity ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("images/city_lat_vs_humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Cloudiness ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("images/city_lat_vs_cloudy.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Wind Speed ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig("images/city_lat_vs_wind_speed.png")

# %%
# Observations

#1.  Latitude vs. Temperature:  It is currently winter in the Northern Hemisphere and Summer in the South
#    Temperature will be high further south of the equator
#    Temperature will be low further north of the equator

#2.  I'm seeing higher humidity in the northern hempisphere, between latitude lines 40-80

#3.  I'm seeing some very windy cities along latitude line 60 on successive runs of my program

#4.  I'm realizing a little too late that I didn't prevent duplicate cities from making it into my data frame.
#    That is probably cluttering my plot.  We'll see if I can make the adjustment by midnight today(12/11 due date)

# %%
weather_data['City'].value_counts()
# Out:
# Cape Town         2
# Timmins           2
# Vaini             2
# Lompoc            2
# Lorengau          2
#                  ..
# Port Lincoln      1
# Kawalu            1
# Ribeira Grande    1
# Ocamonte          1
# Goderich          1
# Name: City, Length: 529, dtype: int64
