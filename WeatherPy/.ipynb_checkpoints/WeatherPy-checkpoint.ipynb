# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
# Had to pip install citipy into my anaconda python 3.7 environment
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 582

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# This is ugly, but I'm slicing my city list down into batches
# I'm sure that there is a more efficient way to do this
# I assume that the batch size of 50 is to preven api key from being blocked?

city_slice1 = cities[0:50]
city_slice2 = cities[50:100]
city_slice3 = cities[100:150]
city_slice4 = cities[150:200]
city_slice5 = cities[200:250]
city_slice6 = cities[250:300]
city_slice7 = cities[300:350]
city_slice8 = cities[350:400]
city_slice9 = cities[400:450]
city_slice10 = cities[450:500]
city_slice11 = cities[500:550]
city_slice12 = cities[550:600]
city_slice13 = cities[600:]

city_slices = [city_slice1,
              city_slice1,
              city_slice2,
              city_slice3,
              city_slice4,
              city_slice5,
              city_slice6,
              city_slice7,
              city_slice8,
              city_slice9,
              city_slice10,
              city_slice11,
              city_slice12,
              city_slice13]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

city_list = []
cloud_list = []
country_list = []
date_list = []
humid_list = []
lat_list = []
long_list = []
temp_max_list = []
wind_list = []

record_num = 1
set_num = 1


# Loop to iterate through cities
# build query url with current city
# get response and append data to lists

print("Beginning Data Retrieval")
print ("-----------------------------")


for slice in city_slices:
    for c in slice:
        try:
            query_url = url + "appid=" + api_key + "&q=" + c + "&units=imperial"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            print(f"Processing Record {record_num} of set {set_num} | {weather_json['name']}" )
            city_list.append(weather_json['name'])
            cloud_list.append(weather_json['clouds']['all'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])
            humid_list.append(weather_json['main']['humidity'])
            lat_list.append(weather_json['coord']['lat'])
            long_list.append(weather_json['coord']['lon'])
            temp_max_list.append(weather_json['main']['temp_max'])
            wind_list.append(weather_json['wind']['speed'])
        except KeyError:
            print(f"Whoops,  City {c} does not exist, skipping")
        record_num +=1
    set_num +=1
    record_num =1              

print ("-----------------------------")
print("Data Retrieval Complete")
print ("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | Jamestown
# Processing Record 2 of set 1 | Hobart
# Processing Record 3 of set 1 | Pisco
# Processing Record 4 of set 1 | Julfa
# Processing Record 5 of set 1 | Victoria
# Processing Record 6 of set 1 | Hilo
# Processing Record 7 of set 1 | Rikitea
# Processing Record 8 of set 1 | Staryy Nadym
# Processing Record 9 of set 1 | Tiksi
# Processing Record 10 of set 1 | Faanui
# Processing Record 11 of set 1 | Albany
# Processing Record 12 of set 1 | Dauphin
# Processing Record 13 of set 1 | Aromashevo
# Processing Record 14 of set 1 | Severo-Kurilsk
# Processing Record 15 of set 1 | East London
# Processing Record 16 of set 1 | Kigoma
# Processing Record 17 of set 1 | Puerto Ayora
# Processing Record 18 of set 1 | Moose Factory
# Processing Record 19 of set 1 | Thompson
# Processing Record 20 of set 1 | Chokurdakh
# Processing Record 21 of set 1 | Bredasdorp
# Processing Record 22 of set 1 | Kapaa
# Processing Record 23 of set 1 | Meulaboh
# Processing Record 24 of set 1 | Yerbogachen
# Processing Record 25 of set 1 | Sinnamary
# Processing Record 26 of set 1 | Punta Arenas
# Processing Record 27 of set 1 | Chuy
# Processing Record 28 of set 1 | Montclair
# Processing Record 29 of set 1 | Nemea
# Whoops,  City taolanaro does not exist, skipping
# Processing Record 31 of set 1 | Kondinskoye
# Processing Record 32 of set 1 | Mennecy
# Processing Record 33 of set 1 | Saskylakh
# Processing Record 34 of set 1 | Vila Franca do Campo
# Processing Record 35 of set 1 | Half Moon Bay
# Processing Record 36 of set 1 | Dukat
# Whoops,  City barentsburg does not exist, skipping
# Processing Record 38 of set 1 | Vilhena
# Processing Record 39 of set 1 | Busselton
# Processing Record 40 of set 1 | Upernavik
# Whoops,  City olafsvik does not exist, skipping
# Processing Record 42 of set 1 | Kavieng
# Processing Record 43 of set 1 | Bara
# Whoops,  City belushya guba does not exist, skipping
# Processing Record 45 of set 1 | Mogadishu
# Processing Record 46 of set 1 | Tasiilaq
# Whoops,  City kargapolye does not exist, skipping
# Processing Record 48 of set 1 | Tarata
# Processing Record 49 of set 1 | Airai
# Processing Record 50 of set 1 | Kruisfontein
# Processing Record 1 of set 2 | Jamestown
# Processing Record 2 of set 2 | Hobart
# Processing Record 3 of set 2 | Pisco
# Processing Record 4 of set 2 | Julfa
# Processing Record 5 of set 2 | Victoria
# Processing Record 6 of set 2 | Hilo
# Processing Record 7 of set 2 | Rikitea
# Processing Record 8 of set 2 | Staryy Nadym
# Processing Record 9 of set 2 | Tiksi
# Processing Record 10 of set 2 | Faanui
# Processing Record 11 of set 2 | Albany
# Processing Record 12 of set 2 | Dauphin
# Processing Record 13 of set 2 | Aromashevo
# Processing Record 14 of set 2 | Severo-Kurilsk
# Processing Record 15 of set 2 | East London
# Processing Record 16 of set 2 | Kigoma
# Processing Record 17 of set 2 | Puerto Ayora
# Processing Record 18 of set 2 | Moose Factory
# Processing Record 19 of set 2 | Thompson
# Processing Record 20 of set 2 | Chokurdakh
# Processing Record 21 of set 2 | Bredasdorp
# Processing Record 22 of set 2 | Kapaa
# Processing Record 23 of set 2 | Meulaboh
# Processing Record 24 of set 2 | Yerbogachen
# Processing Record 25 of set 2 | Sinnamary
# Processing Record 26 of set 2 | Punta Arenas
# Processing Record 27 of set 2 | Chuy
# Processing Record 28 of set 2 | Montclair
# Processing Record 29 of set 2 | Nemea
# Whoops,  City taolanaro does not exist, skipping
# Processing Record 31 of set 2 | Kondinskoye
# Processing Record 32 of set 2 | Mennecy
# Processing Record 33 of set 2 | Saskylakh
# Processing Record 34 of set 2 | Vila Franca do Campo
# Processing Record 35 of set 2 | Half Moon Bay
# Processing Record 36 of set 2 | Dukat
# Whoops,  City barentsburg does not exist, skipping
# Processing Record 38 of set 2 | Vilhena
# Processing Record 39 of set 2 | Busselton
# Processing Record 40 of set 2 | Upernavik
# Whoops,  City olafsvik does not exist, skipping
# Processing Record 42 of set 2 | Kavieng
# Processing Record 43 of set 2 | Bara
# Whoops,  City belushya guba does not exist, skipping
# Processing Record 45 of set 2 | Mogadishu
# Processing Record 46 of set 2 | Tasiilaq
# Whoops,  City kargapolye does not exist, skipping
# Processing Record 48 of set 2 | Tarata
# Processing Record 49 of set 2 | Airai
# Processing Record 50 of set 2 | Kruisfontein
# Processing Record 1 of set 3 | Bethel
# Processing Record 2 of set 3 | Acajutla
# Processing Record 3 of set 3 | San Patricio
# Processing Record 4 of set 3 | Mataura
# Whoops,  City mys shmidta does not exist, skipping
# Processing Record 6 of set 3 | Mirandela
# Whoops,  City tsihombe does not exist, skipping
# Processing Record 8 of set 3 | Nanortalik
# Whoops,  City vaitupu does not exist, skipping
# Processing Record 10 of set 3 | Castro
# Processing Record 11 of set 3 | Torbay
# Processing Record 12 of set 3 | Tuktoyaktuk
# Processing Record 13 of set 3 | Vardo
# Processing Record 14 of set 3 | Butaritari
# Processing Record 15 of set 3 | Saint-Augustin
# Whoops,  City nizhneyansk does not exist, skipping
# Processing Record 17 of set 3 | Khatanga
# Processing Record 18 of set 3 | Nikolskoye
# Processing Record 19 of set 3 | Ouallam
# Processing Record 20 of set 3 | Aykhal
# Whoops,  City buqayq does not exist, skipping
# Processing Record 22 of set 3 | Sembakung
# Processing Record 23 of set 3 | Ushuaia
# Processing Record 24 of set 3 | Broome
# Processing Record 25 of set 3 | Kinablangan
# Processing Record 26 of set 3 | Birao
# Processing Record 27 of set 3 | Constitucion
# Processing Record 28 of set 3 | Mar del Plata
# Whoops,  City krasnoselkup does not exist, skipping
# Processing Record 30 of set 3 | Khandyga
# Processing Record 31 of set 3 | Mount Isa
# Processing Record 32 of set 3 | Santa Luzia
# Processing Record 33 of set 3 | Cidreira
# Processing Record 34 of set 3 | Namatanai
# Whoops,  City sakakah does not exist, skipping
# Processing Record 36 of set 3 | Atuona
# Whoops,  City illoqqortoormiut does not exist, skipping
# Processing Record 38 of set 3 | Cape Town
# Processing Record 39 of set 3 | Chichli
# Whoops,  City chagda does not exist, skipping
# Processing Record 41 of set 3 | Oster
# Processing Record 42 of set 3 | Knysna
# Processing Record 43 of set 3 | San Quintin
# Processing Record 44 of set 3 | Buzmeyin
# Processing Record 45 of set 3 | Avarua
# Processing Record 46 of set 3 | Katsuura
# Processing Record 47 of set 3 | Ahar
# Processing Record 48 of set 3 | Yellowknife
# Processing Record 49 of set 3 | Viedma
# Processing Record 50 of set 3 | Ketchikan
# Processing Record 1 of set 4 | Paamiut
# Processing Record 2 of set 4 | Salalah
# Processing Record 3 of set 4 | Barrow
# Processing Record 4 of set 4 | Curillo
# Processing Record 5 of set 4 | Hermanus
# Processing Record 6 of set 4 | Pilar
# Processing Record 7 of set 4 | Port Alfred
# Whoops,  City tabiauea does not exist, skipping
# Processing Record 9 of set 4 | Polewali
# Processing Record 10 of set 4 | Youhao
# Processing Record 11 of set 4 | Mitu
# Processing Record 12 of set 4 | Vaini
# Processing Record 13 of set 4 | Sorland
# Processing Record 14 of set 4 | Mahebourg
# Processing Record 15 of set 4 | Ilulissat
# Processing Record 16 of set 4 | Namibe
# Processing Record 17 of set 4 | Quatre Cocos
# Processing Record 18 of set 4 | Hamilton
# Processing Record 19 of set 4 | Kampong Cham
# Processing Record 20 of set 4 | Ribeira Grande
# Processing Record 21 of set 4 | Norman Wells
# Processing Record 22 of set 4 | Hajnowka
# Processing Record 23 of set 4 | Tiznit
# Processing Record 24 of set 4 | Lavrentiya
# Processing Record 25 of set 4 | Harindanga
# Processing Record 26 of set 4 | Lebu
# Processing Record 27 of set 4 | Mugur-Aksy
# Processing Record 28 of set 4 | Kovur
# Processing Record 29 of set 4 | Lasa
# Processing Record 30 of set 4 | Bandarbeyla
# Processing Record 31 of set 4 | Dikson
# Whoops,  City marcona does not exist, skipping
# Processing Record 33 of set 4 | Oum Hadjer
# Processing Record 34 of set 4 | San Rafael
# Processing Record 35 of set 4 | Inhambane
# Processing Record 36 of set 4 | Bluff
# Processing Record 37 of set 4 | Linxia
# Processing Record 38 of set 4 | Malatya
# Processing Record 39 of set 4 | Cayenne
# Processing Record 40 of set 4 | Arlit
# Processing Record 41 of set 4 | Kavaratti
# Processing Record 42 of set 4 | Husavik
# Whoops,  City kemijarvi does not exist, skipping
# Processing Record 44 of set 4 | Hofn
# Processing Record 45 of set 4 | Port Elizabeth
# Processing Record 46 of set 4 | Graham
# Processing Record 47 of set 4 | Fort Nelson
# Processing Record 48 of set 4 | Nioro
# Processing Record 49 of set 4 | Abnub
# Processing Record 50 of set 4 | Necochea
# Processing Record 1 of set 5 | Dobryanka
# Processing Record 2 of set 5 | Beringovskiy
# Processing Record 3 of set 5 | Margate
# Processing Record 4 of set 5 | Deputatskiy
# Processing Record 5 of set 5 | Kyzyl-Suu
# Processing Record 6 of set 5 | Chocope
# Processing Record 7 of set 5 | Whitianga
# Whoops,  City amderma does not exist, skipping
# Whoops,  City eskasem does not exist, skipping
# Processing Record 10 of set 5 | Nome
# Processing Record 11 of set 5 | Vinukonda
# Processing Record 12 of set 5 | Okhotsk
# Processing Record 13 of set 5 | Novoagansk
# Processing Record 14 of set 5 | Gifhorn
# Processing Record 15 of set 5 | Hithadhoo
# Whoops,  City zlatoustovsk does not exist, skipping
# Processing Record 17 of set 5 | Mehamn
# Whoops,  City hihifo does not exist, skipping
# Processing Record 19 of set 5 | New Norfolk
# Processing Record 20 of set 5 | High Level
# Processing Record 21 of set 5 | Sestri Levante
# Processing Record 22 of set 5 | Klaksvik
# Processing Record 23 of set 5 | Kenai
# Processing Record 24 of set 5 | Kasempa
# Processing Record 25 of set 5 | Lespezi
# Processing Record 26 of set 5 | Ostrovnoy
# Processing Record 27 of set 5 | Dunedin
# Processing Record 28 of set 5 | Lerwick
# Processing Record 29 of set 5 | Bonga
# Processing Record 30 of set 5 | Umm Lajj
# Processing Record 31 of set 5 | Virginia Beach
# Processing Record 32 of set 5 | Morgan City
# Processing Record 33 of set 5 | Tura
# Whoops,  City cam pha does not exist, skipping
# Processing Record 35 of set 5 | Caravelas
# Processing Record 36 of set 5 | Northam
# Processing Record 37 of set 5 | Sandpoint
# Whoops,  City garm does not exist, skipping
# Processing Record 39 of set 5 | Shenjiamen
# Processing Record 40 of set 5 | Maldonado
# Processing Record 41 of set 5 | Tual
# Processing Record 42 of set 5 | Lannion
# Processing Record 43 of set 5 | Chipinge
# Processing Record 44 of set 5 | Dubbo
# Processing Record 45 of set 5 | Bambous Virieux
# Processing Record 46 of set 5 | Saint George
# Processing Record 47 of set 5 | Sioux Lookout
# Processing Record 48 of set 5 | Qaanaaq
# Processing Record 49 of set 5 | Sao Joao Batista
# Processing Record 50 of set 5 | Maumere
# Processing Record 1 of set 6 | Moerai
# Processing Record 2 of set 6 | Kungurtug
# Processing Record 3 of set 6 | Monster
# Processing Record 4 of set 6 | Saint-Philippe
# Processing Record 5 of set 6 | Kangaatsiaq
# Processing Record 6 of set 6 | Hami
# Whoops,  City asau does not exist, skipping
# Processing Record 8 of set 6 | Longyearbyen
# Processing Record 9 of set 6 | Labuhan
# Processing Record 10 of set 6 | Antofagasta
# Processing Record 11 of set 6 | Sao Filipe
# Processing Record 12 of set 6 | Charters Towers
# Processing Record 13 of set 6 | Esperance
# Processing Record 14 of set 6 | Batesville
# Processing Record 15 of set 6 | Luderitz
# Processing Record 16 of set 6 | Tuatapere
# Processing Record 17 of set 6 | Codrington
# Processing Record 18 of set 6 | Veraval
# Processing Record 19 of set 6 | Bucerias
# Processing Record 20 of set 6 | Coquimbo
# Processing Record 21 of set 6 | Komsomolskiy
# Processing Record 22 of set 6 | West Wendover
# Processing Record 23 of set 6 | Pembroke
# Processing Record 24 of set 6 | Hualmay
# Processing Record 25 of set 6 | Guardiagrele
# Whoops,  City satitoa does not exist, skipping
# Whoops,  City mauswagon does not exist, skipping
# Processing Record 28 of set 6 | Puerto El Triunfo
# Whoops,  City abiy adi does not exist, skipping
# Processing Record 30 of set 6 | Beloha
# Processing Record 31 of set 6 | Muli
# Processing Record 32 of set 6 | Arraial do Cabo
# Processing Record 33 of set 6 | Trofors
# Whoops,  City tidore does not exist, skipping
# Processing Record 35 of set 6 | Surt
# Processing Record 36 of set 6 | Llangefni
# Processing Record 37 of set 6 | Ust-Nera
# Whoops,  City sentyabrskiy does not exist, skipping
# Processing Record 39 of set 6 | Geraldton
# Processing Record 40 of set 6 | Sisimiut
# Processing Record 41 of set 6 | Tarnok
# Processing Record 42 of set 6 | Rio Gallegos
# Processing Record 43 of set 6 | Soyo
# Processing Record 44 of set 6 | Kaitangata
# Processing Record 45 of set 6 | Bulancak
# Processing Record 46 of set 6 | Sabang
# Processing Record 47 of set 6 | Ahipara
# Processing Record 48 of set 6 | Nioki
# Whoops,  City gangotri does not exist, skipping
# Processing Record 50 of set 6 | Georgetown
# Processing Record 1 of set 7 | Bluefield
# Whoops,  City samusu does not exist, skipping
# Processing Record 3 of set 7 | Muros
# Processing Record 4 of set 7 | Souillac
# Processing Record 5 of set 7 | Cabo San Lucas
# Processing Record 6 of set 7 | Cap Malheureux
# Processing Record 7 of set 7 | Loukhi
# Processing Record 8 of set 7 | Balkanabat
# Processing Record 9 of set 7 | Adrar
# Processing Record 10 of set 7 | Wainwright
# Processing Record 11 of set 7 | Itarema
# Processing Record 12 of set 7 | Balakhta
# Processing Record 13 of set 7 | Zharkent
# Processing Record 14 of set 7 | Benemerito de las Americas
# Processing Record 15 of set 7 | Nanakuli
# Processing Record 16 of set 7 | Pevek
# Processing Record 17 of set 7 | Pipri
# Processing Record 18 of set 7 | Sibu
# Processing Record 19 of set 7 | The Valley
# Processing Record 20 of set 7 | Sao Joao da Barra
# Processing Record 21 of set 7 | Tilichiki
# Processing Record 22 of set 7 | Dunda
# Processing Record 23 of set 7 | Najran
# Processing Record 24 of set 7 | Lompoc
# Processing Record 25 of set 7 | Sakassou
# Processing Record 26 of set 7 | Richards Bay
# Processing Record 27 of set 7 | Los Llanos de Aridane
# Whoops,  City qui nhon does not exist, skipping
# Processing Record 29 of set 7 | Touros
# Processing Record 30 of set 7 | San Mateo del Mar
# Processing Record 31 of set 7 | Talnakh
# Processing Record 32 of set 7 | Wexford
# Processing Record 33 of set 7 | Omsk
# Processing Record 34 of set 7 | Porto Seguro
# Processing Record 35 of set 7 | Aljezur
# Processing Record 36 of set 7 | Zambezi
# Processing Record 37 of set 7 | Westport
# Processing Record 38 of set 7 | Englewood
# Processing Record 39 of set 7 | Lorengau
# Processing Record 40 of set 7 | Dingle
# Processing Record 41 of set 7 | Maragogi
# Processing Record 42 of set 7 | Rawlins
# Processing Record 43 of set 7 | Puerto Baquerizo Moreno
# Processing Record 44 of set 7 | Hasaki
# Processing Record 45 of set 7 | Kodiak
# Processing Record 46 of set 7 | Erenhot
# Processing Record 47 of set 7 | Juba
# Processing Record 48 of set 7 | Yaan
# Processing Record 49 of set 7 | Marystown
# Processing Record 50 of set 7 | Orlik
# Processing Record 1 of set 8 | Khanpur
# Processing Record 2 of set 8 | Camacha
# Processing Record 3 of set 8 | Houma
# Processing Record 4 of set 8 | Faya
# Processing Record 5 of set 8 | Sao Benedito do Rio Preto
# Whoops,  City umzimvubu does not exist, skipping
# Processing Record 7 of set 8 | Rock Hill
# Processing Record 8 of set 8 | Harper
# Processing Record 9 of set 8 | Mont-de-Marsan
# Processing Record 10 of set 8 | Henderson
# Processing Record 11 of set 8 | Chapais
# Processing Record 12 of set 8 | Alyangula
# Processing Record 13 of set 8 | Clyde River
# Processing Record 14 of set 8 | Hammerfest
# Processing Record 15 of set 8 | Avera
# Processing Record 16 of set 8 | Fairbanks
# Processing Record 17 of set 8 | Diego de Almagro
# Processing Record 18 of set 8 | Mikhaylovka
# Processing Record 19 of set 8 | Morondava
# Processing Record 20 of set 8 | Thinadhoo
# Whoops,  City bobonong does not exist, skipping
# Processing Record 22 of set 8 | Cartagena
# Processing Record 23 of set 8 | Cadillac
# Processing Record 24 of set 8 | Rocha
# Processing Record 25 of set 8 | Agadez
# Processing Record 26 of set 8 | Saint-Pierre
# Processing Record 27 of set 8 | Verkhovyna
# Processing Record 28 of set 8 | Iralaya
# Processing Record 29 of set 8 | Belz
# Processing Record 30 of set 8 | Cheney
# Whoops,  City cockburn harbour does not exist, skipping
# Processing Record 32 of set 8 | Zeya
# Processing Record 33 of set 8 | Batticaloa
# Processing Record 34 of set 8 | Benito Juarez
# Processing Record 35 of set 8 | Emerald
# Processing Record 36 of set 8 | Guerrero Negro
# Processing Record 37 of set 8 | Cooma
# Whoops,  City attawapiskat does not exist, skipping
# Processing Record 39 of set 8 | Shamkhal
# Processing Record 40 of set 8 | Oranjestad
# Processing Record 41 of set 8 | Vostok
# Processing Record 42 of set 8 | Tevaitoa
# Processing Record 43 of set 8 | Huarmey
# Whoops,  City tumannyy does not exist, skipping
# Processing Record 45 of set 8 | Comodoro Rivadavia
# Processing Record 46 of set 8 | Quelimane
# Processing Record 47 of set 8 | Sambava
# Processing Record 48 of set 8 | Poum
# Processing Record 49 of set 8 | Cherskiy
# Processing Record 50 of set 8 | Bangassou
# Processing Record 1 of set 9 | Bonthe
# Processing Record 2 of set 9 | Berlevag
# Processing Record 3 of set 9 | El Cobre
# Processing Record 4 of set 9 | Sitka
# Processing Record 5 of set 9 | Aksu
# Processing Record 6 of set 9 | Laguna
# Whoops,  City bairiki does not exist, skipping
# Processing Record 8 of set 9 | Takaungu
# Processing Record 9 of set 9 | Riohacha
# Processing Record 10 of set 9 | Aswan
# Processing Record 11 of set 9 | Leh
# Processing Record 12 of set 9 | Isparta
# Processing Record 13 of set 9 | Vila Velha
# Processing Record 14 of set 9 | Gobabis
# Processing Record 15 of set 9 | Nortelandia
# Processing Record 16 of set 9 | Visnes
# Processing Record 17 of set 9 | Mareeba
# Processing Record 18 of set 9 | Brae
# Processing Record 19 of set 9 | Provideniya
# Processing Record 20 of set 9 | Portoferraio
# Processing Record 21 of set 9 | Aran
# Processing Record 22 of set 9 | Pozo Colorado
# Processing Record 23 of set 9 | Jackson
# Processing Record 24 of set 9 | Alofi
# Processing Record 25 of set 9 | Kloulklubed
# Processing Record 26 of set 9 | Menongue
# Processing Record 27 of set 9 | Nemuro
# Processing Record 28 of set 9 | Hambantota
# Processing Record 29 of set 9 | Carnarvon
# Whoops,  City dzhusaly does not exist, skipping
# Processing Record 31 of set 9 | Motygino
# Processing Record 32 of set 9 | Peleduy
# Processing Record 33 of set 9 | Beasain
# Processing Record 34 of set 9 | Hobyo
# Processing Record 35 of set 9 | College
# Processing Record 36 of set 9 | Vestmannaeyjar
# Processing Record 37 of set 9 | Zhigansk
# Processing Record 38 of set 9 | Tara
# Processing Record 39 of set 9 | Nantucket
# Processing Record 40 of set 9 | Samarai
# Processing Record 41 of set 9 | Manado
# Processing Record 42 of set 9 | Leningradskiy
# Processing Record 43 of set 9 | Usinsk
# Processing Record 44 of set 9 | Ko Samui
# Processing Record 45 of set 9 | Marrakesh
# Processing Record 46 of set 9 | Nokaneng
# Processing Record 47 of set 9 | Puri
# Processing Record 48 of set 9 | Awbari
# Processing Record 49 of set 9 | Alhandra
# Processing Record 50 of set 9 | Mabaruma
# Processing Record 1 of set 10 | Porbandar
# Processing Record 2 of set 10 | Natal
# Whoops,  City korla does not exist, skipping
# Processing Record 4 of set 10 | Portland
# Processing Record 5 of set 10 | Otautau
# Processing Record 6 of set 10 | Jonkoping
# Processing Record 7 of set 10 | Karratha
# Processing Record 8 of set 10 | Bonavista
# Processing Record 9 of set 10 | Znamenskoye
# Processing Record 10 of set 10 | Zwiesel
# Processing Record 11 of set 10 | Kavarna
# Processing Record 12 of set 10 | Sebezh
# Processing Record 13 of set 10 | Tautira
# Processing Record 14 of set 10 | Kamenka
# Processing Record 15 of set 10 | Isangel
# Processing Record 16 of set 10 | Barcelos
# Whoops,  City karaul does not exist, skipping
# Processing Record 18 of set 10 | Grindavik
# Whoops,  City bengkulu does not exist, skipping
# Processing Record 20 of set 10 | China
# Processing Record 21 of set 10 | Gallup
# Processing Record 22 of set 10 | Pacific Grove
# Processing Record 23 of set 10 | Reconquista
# Processing Record 24 of set 10 | Teya
# Processing Record 25 of set 10 | Columbus
# Processing Record 26 of set 10 | Heishan
# Processing Record 27 of set 10 | La Ronge
# Processing Record 28 of set 10 | Noumea
# Processing Record 29 of set 10 | Zalantun
# Whoops,  City monatele does not exist, skipping
# Whoops,  City meyungs does not exist, skipping
# Processing Record 32 of set 10 | Vila do Maio
# Processing Record 33 of set 10 | Chivilcoy
# Processing Record 34 of set 10 | Ponto Novo
# Processing Record 35 of set 10 | Bhinga
# Processing Record 36 of set 10 | Wichian Buri
# Processing Record 37 of set 10 | Srednekolymsk
# Processing Record 38 of set 10 | Belmonte
# Processing Record 39 of set 10 | Lodja
# Processing Record 40 of set 10 | Kununurra
# Processing Record 41 of set 10 | Magole
# Processing Record 42 of set 10 | Redcliffe
# Whoops,  City grand river south east does not exist, skipping
# Processing Record 44 of set 10 | Ancud
# Processing Record 45 of set 10 | Turtas
# Processing Record 46 of set 10 | Beckley
# Processing Record 47 of set 10 | Derzhavinsk
# Whoops,  City safaga does not exist, skipping
# Processing Record 49 of set 10 | Honiara
# Processing Record 50 of set 10 | Santa Cruz
# Whoops,  City duz does not exist, skipping
# Processing Record 2 of set 11 | Banjarmasin
# Processing Record 3 of set 11 | Biloela
# Processing Record 4 of set 11 | Ust-Ishim
# Processing Record 5 of set 11 | Fortuna
# Whoops,  City kapoeta does not exist, skipping
# Processing Record 7 of set 11 | Salym
# Processing Record 8 of set 11 | Krasnoborsk
# Processing Record 9 of set 11 | Madimba
# Processing Record 10 of set 11 | Kahului
# Processing Record 11 of set 11 | Badvel
# Processing Record 12 of set 11 | Egvekinot
# Processing Record 13 of set 11 | San Policarpo
# Processing Record 14 of set 11 | Padang
# Processing Record 15 of set 11 | Jhelum
# Processing Record 16 of set 11 | Broken Hill
# Processing Record 17 of set 11 | Shimoda
# Whoops,  City ruatoria does not exist, skipping
# Processing Record 19 of set 11 | Fallon
# Processing Record 20 of set 11 | Santa Marinella
# Processing Record 21 of set 11 | Darhan
# Processing Record 22 of set 11 | Fort-Shevchenko
# Processing Record 23 of set 11 | Springbok
# Processing Record 24 of set 11 | North Bend
# Processing Record 25 of set 11 | Cockburn Town
# Processing Record 26 of set 11 | Alice Springs
# Processing Record 27 of set 11 | Toamasina
# Processing Record 28 of set 11 | Lixourion
# Processing Record 29 of set 11 | Guane
# Processing Record 30 of set 11 | Zhangjiakou
# Processing Record 31 of set 11 | Vao
# Processing Record 32 of set 11 | Luganville
# Processing Record 33 of set 11 | Porto Novo
# Processing Record 34 of set 11 | Port Hardy
# Processing Record 35 of set 11 | Walvis Bay
# Processing Record 36 of set 11 | Kieta
# Processing Record 37 of set 11 | Parry Sound
# Processing Record 38 of set 11 | Mutoko
# Processing Record 39 of set 11 | Gigmoto
# Processing Record 40 of set 11 | Zharkovskiy
# Processing Record 41 of set 11 | Whitehorse
# Processing Record 42 of set 11 | Chauk
# Processing Record 43 of set 11 | Gizo
# Processing Record 44 of set 11 | Bordighera
# Processing Record 45 of set 11 | Nuuk
# Processing Record 46 of set 11 | Haines Junction
# Processing Record 47 of set 11 | Colac
# Whoops,  City cah ab does not exist, skipping
# Processing Record 49 of set 11 | Faenza
# Processing Record 50 of set 11 | Biak
# Processing Record 1 of set 12 | Gornopravdinsk
# Processing Record 2 of set 12 | Port-Gentil
# Processing Record 3 of set 12 | Koumac
# Processing Record 4 of set 12 | Anamur
# Processing Record 5 of set 12 | Otradnoye
# Processing Record 6 of set 12 | Cascas
# Whoops,  City palabuhanratu does not exist, skipping
# Processing Record 8 of set 12 | Mahanoro
# Processing Record 9 of set 12 | Vila
# Processing Record 10 of set 12 | Bilma
# Processing Record 11 of set 12 | Yatou
# Processing Record 12 of set 12 | Oranjemund
# Processing Record 13 of set 12 | Lakatoro
# Processing Record 14 of set 12 | Siria
# Processing Record 15 of set 12 | Ibra
# Processing Record 16 of set 12 | Savannah Bight
# Processing Record 17 of set 12 | Fare
# Processing Record 18 of set 12 | Lima
# Processing Record 19 of set 12 | Aasiaat
# Processing Record 20 of set 12 | Port Hedland
# Processing Record 21 of set 12 | Bestobe
# Processing Record 22 of set 12 | Coihaique
# Processing Record 23 of set 12 | Seoul
# Processing Record 24 of set 12 | Bambanglipuro
# Processing Record 25 of set 12 | Topeka
# Whoops,  City jinchengjiang does not exist, skipping
# Processing Record 27 of set 12 | Coahuayana
# Whoops,  City kegayli does not exist, skipping
# Whoops,  City kuche does not exist, skipping
# Processing Record 30 of set 12 | Coruripe
# Processing Record 31 of set 12 | Nhulunbuy
# Processing Record 32 of set 12 | Poniatowa
# Processing Record 33 of set 12 | Boleslawiec
# Processing Record 34 of set 12 | Wahiawa
# Processing Record 35 of set 12 | Wladyslawowo
# Processing Record 36 of set 12 | Zheleznodorozhnyy
# Processing Record 37 of set 12 | Soke
# Processing Record 38 of set 12 | Tabas
# Processing Record 39 of set 12 | Baykit
# Processing Record 40 of set 12 | Zyryanka
# Processing Record 41 of set 12 | Mayor Pablo Lagerenza
# Processing Record 42 of set 12 | Nouadhibou
# Processing Record 43 of set 12 | Gombong
# Processing Record 44 of set 12 | Bakuriani
# Processing Record 45 of set 12 | Darab
# Processing Record 46 of set 12 | Xingcheng
# Whoops,  City bengkalis does not exist, skipping
# Whoops,  City acarau does not exist, skipping
# Processing Record 49 of set 12 | Port Blair
# Processing Record 50 of set 12 | Shingu
# Processing Record 1 of set 13 | Ngorongoro
# Processing Record 2 of set 13 | Tortoli
# Processing Record 3 of set 13 | Zelenoborskiy
# Processing Record 4 of set 13 | Camalu
# Whoops,  City pingchen does not exist, skipping
# Whoops,  City saleaula does not exist, skipping
# Processing Record 7 of set 13 | Pangnirtung
# Processing Record 8 of set 13 | Pointe Michel
# Whoops,  City sofiysk does not exist, skipping
# Processing Record 10 of set 13 | Drumnadrochit
# Processing Record 11 of set 13 | Udimskiy
# Whoops,  City kyra does not exist, skipping
# Processing Record 13 of set 13 | Binzhou
# Whoops,  City ust-kamchatsk does not exist, skipping
# Processing Record 15 of set 13 | Riyadh
# Processing Record 16 of set 13 | Suicheng
# Processing Record 17 of set 13 | Xiongyue
# Processing Record 18 of set 13 | Albanel
# Processing Record 19 of set 13 | Bilibino
# Processing Record 20 of set 13 | Pokrovskoye
# Processing Record 21 of set 13 | Jalu
# Processing Record 22 of set 13 | Mkushi
# Processing Record 23 of set 13 | Shahrud
# Processing Record 24 of set 13 | Tahe
# Processing Record 25 of set 13 | Grand Gaube
# Processing Record 26 of set 13 | Flinders
# Processing Record 27 of set 13 | Luanda
# Processing Record 28 of set 13 | Bahar
# Whoops,  City zachagansk does not exist, skipping
# Processing Record 30 of set 13 | Phuket
# Processing Record 31 of set 13 | Whithorn
# Processing Record 32 of set 13 | Havre-Saint-Pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloud_list,
    "Country": country_list,
    "Date": date_list,
    "Humidity": humid_list,
    "Lat": lat_list,
    "Lng": long_list,
    "Max Temp": temp_max_list,
    "Wind Speed": wind_list
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
weather_data.to_csv('output/weather_data.csv', encoding='utf-8')

# %%
weather_data.head(5)
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Jamestown           0      AU  1576055060        36 -33.21  138.60
# 1     Hobart          75      AU  1576055225        63 -42.88  147.33
# 2      Pisco          75      PE  1576055225        88 -13.71  -76.20
# 3      Julfa          90      AZ  1576055225        86  38.95   45.63
# 4   Victoria          75      BN  1576055225        83   5.28  115.24
#
#    Max Temp  Wind Speed
# 0     72.88       16.51
# 1     66.00        9.17
# 2     66.99        5.82
# 3     37.40        9.17
# 4     82.40        6.93

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Max Temperature ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("images/city_lat_vs_max_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Humidity ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("images/city_lat_vs_humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Cloudiness ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("images/city_lat_vs_cloudy.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="black")

plot_date = time.strftime('%d/%m/%y')
title_txt = f"City Latitude vs. Wind Speed ({plot_date})"
plt.title(title_txt)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig("images/city_lat_vs_wind_speed.png")

# %%
# Observations

#1.  Latitude vs. Temperature:  It is currently winter in the Northern Hemisphere and Summer in the South
#    Temperature will be high further south of the equator
#    Temperature will be low further north of the equator

#2.  I'm seeing higher humidity in the northern hempisphere, between latitude lines 40-80

#3.  I'm seeing some very windy cities along latitude line 60 on successive runs of my program
